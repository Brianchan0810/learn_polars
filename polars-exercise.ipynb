# %%
import polars as pl
import pandas as pd
import numpy as np
import time 
import json
import vaex
from datetime import datetime

# %%
df = pl.read_csv('data.csv')

# %%
csv = """
0,                            Would never order again.
1,   I'm not sure it gives me any type of glow and ...
2,   Goes on smoothly a bit sticky and color is clo...
3,       Preferisco altri prodotti della stessa marca.
4,        The moisturizing advertised is non-existent.
""".encode()

(pl.read_csv(csv, has_header=False, new_columns=["idx", "lines"])
    .select(pl.col("lines").str.split(" ").alias("words"))
)
# Out:
# shape: (5, 1)
# ┌───────────────────────────────┐
# │ words                         │
# │ ---                           │
# │ list[str]                     │
# ╞═══════════════════════════════╡
# │ ["", "", ... "again."]        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ["", "", ... "..."]           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ["", "", ... "clo..."]        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ["", "", ... "marca."]        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ["", "", ... "non-existent."] │
# └───────────────────────────────┘

# %% [markdown]
# ## Dataframe slicing

# %%
df.head(1)
# Out:
# shape: (1, 10)
# ┌───────┬───────┬───────┬─────────┬─────┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut   ┆ color ┆ clarity ┆ ... ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---   ┆ ---   ┆ ---     ┆     ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str   ┆ str   ┆ str     ┆     ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════╪═══════╪═════════╪═════╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal ┆ E     ┆ SI2     ┆ ... ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# └───────┴───────┴───────┴─────────┴─────┴───────┴──────┴──────┴──────┘

# %%
df.tail(1)
# Out:
# shape: (1, 10)
# ┌───────┬───────┬───────┬─────────┬─────┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut   ┆ color ┆ clarity ┆ ... ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---   ┆ ---   ┆ ---     ┆     ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str   ┆ str   ┆ str     ┆     ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════╪═══════╪═════════╪═════╪═══════╪══════╪══════╪══════╡
# │ 0.75  ┆ Ideal ┆ D     ┆ SI2     ┆ ... ┆ 2757  ┆ 5.83 ┆ 5.87 ┆ 3.64 │
# └───────┴───────┴───────┴─────────┴─────┴───────┴──────┴──────┴──────┘

# %% [markdown]
# ## Dataframe info

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.columns
# Out:
# ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
df.dtypes
# Out:
# [polars.datatypes.Float64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Int64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64]

# %%
df.to_pandas().describe() # no inherent fucntion of describe of polars
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# # Tackle null value

# %%
df = pl.DataFrame({"a": [1, None, None, 4],"b": [0.5, 4, None, 13]})

# %%
df.null_count()
# Out:
# shape: (1, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ u32 ┆ u32 │
# ╞═════╪═════╡
# │ 2   ┆ 1   │
# └─────┴─────┘

# %%
df.with_columns([pl.col('a').fill_null('backward'), pl.col('b').fill_null('mean')])
# Out:
# shape: (4, 2)
# ┌─────┬──────────┐
# │ a   ┆ b        │
# │ --- ┆ ---      │
# │ i64 ┆ f64      │
# ╞═════╪══════════╡
# │ 1   ┆ 0.5      │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 4   ┆ 4.0      │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 4   ┆ 5.833333 │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 4   ┆ 13.0     │
# └─────┴──────────┘

# %%
df.drop_nulls()
# Out:
# shape: (2, 2)
# ┌─────┬──────┐
# │ a   ┆ b    │
# │ --- ┆ ---  │
# │ i64 ┆ f64  │
# ╞═════╪══════╡
# │ 1   ┆ 0.5  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 4   ┆ 13.0 │
# └─────┴──────┘

# %%
df.filter(~pl.fold(acc=True,f=lambda acc, s: acc & s.is_null(),exprs=pl.all(),)) # drop the rows only all vlaues are null
# Out:
# shape: (3, 2)
# ┌──────┬──────┐
# │ a    ┆ b    │
# │ ---  ┆ ---  │
# │ i64  ┆ f64  │
# ╞══════╪══════╡
# │ 1    ┆ 0.5  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ null ┆ 4.0  │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 4    ┆ 13.0 │
# └──────┴──────┘

# %% [markdown]
# # Filtering

# %%
df = pl.DataFrame(
    {
        "id": [1, 2, 3],
        "color": ["blue", "red", "green"],
        "size": ["small", "medium", "large"],
    }
)

# %%
df.filter(pl.col("id") <= 2)
# Out:
# shape: (2, 3)
# ┌─────┬───────┬────────┐
# │ id  ┆ color ┆ size   │
# │ --- ┆ ---   ┆ ---    │
# │ i64 ┆ str   ┆ str    │
# ╞═════╪═══════╪════════╡
# │ 1   ┆ blue  ┆ small  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 2   ┆ red   ┆ medium │
# └─────┴───────┴────────┘

# %%
df.filter((pl.col("id") <= 2) & (pl.col("size") == "small"))
# Out:
# {'id': {0: 1}, 'color': {0: 'blue'}, 'size': {0: 'small'}}

# %% [markdown]
# # String related

# %%
df = pl.DataFrame({"word": "The man ate a whole cake and the end".split(" ")})

# %%
df.with_columns(pl.col("word").str.to_uppercase().alias("uppercase"))
# Out:
# shape: (9, 2)
# ┌──────┬───────────┐
# │ word ┆ uppercase │
# │ ---  ┆ ---       │
# │ str  ┆ str       │
# ╞══════╪═══════════╡
# │ The  ┆ THE       │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ man  ┆ MAN       │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ate  ┆ ATE       │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ a    ┆ A         │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...  ┆ ...       │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ cake ┆ CAKE      │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ and  ┆ AND       │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ the  ┆ THE       │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ end  ┆ END       │
# └──────┴───────────┘

# %%
df.with_columns(pl.col("word").str.lengths().alias("letter_count"))
# Out:
# shape: (9, 2)
# ┌──────┬──────────────┐
# │ word ┆ letter_count │
# │ ---  ┆ ---          │
# │ str  ┆ u32          │
# ╞══════╪══════════════╡
# │ The  ┆ 3            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ man  ┆ 3            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ate  ┆ 3            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ a    ┆ 1            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...  ┆ ...          │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ cake ┆ 4            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ and  ┆ 3            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ the  ┆ 3            │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ end  ┆ 3            │
# └──────┴──────────────┘

# %%
df.filter(pl.col("word").str.contains(r"(?i)^the$|^a$|Cake").is_not())
# Out:
# shape: (5, 1)
# ┌───────┐
# │ word  │
# │ ---   │
# │ str   │
# ╞═══════╡
# │ man   │
# ├╌╌╌╌╌╌╌┤
# │ ate   │
# ├╌╌╌╌╌╌╌┤
# │ whole │
# ├╌╌╌╌╌╌╌┤
# │ and   │
# ├╌╌╌╌╌╌╌┤
# │ end   │
# └───────┘

# %%
df = pl.DataFrame({"a": ["a", "b", "c"],"b": [1, 2, 3]})
df.select([pl.concat_str(["a", "b"]).alias('a+b')])
# Out:
# shape: (3, 1)
# ┌─────┐
# │ a+b │
# │ --- │
# │ str │
# ╞═════╡
# │ a1  │
# ├╌╌╌╌╌┤
# │ b2  │
# ├╌╌╌╌╌┤
# │ c3  │
# └─────┘

# %% [markdown]
# # Datetime related

# %%
df = pl.DataFrame({"date": ["2020-01-01", "2020-02-03", "2020-03-04"], "index": [1, 2, 3]})
df
# Out:
# shape: (3, 2)
# ┌────────────┬───────┐
# │ date       ┆ index │
# │ ---        ┆ ---   │
# │ str        ┆ i64   │
# ╞════════════╪═══════╡
# │ 2020-01-01 ┆ 1     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2020-02-03 ┆ 2     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2020-03-04 ┆ 3     │
# └────────────┴───────┘

# %%
df_time_converted = df.with_columns(pl.col("date").str.strptime(pl.Date, "%Y-%m-%d"))

# %%
df_time_converted.with_columns(pl.col("date").is_between(datetime(2020, 1, 1), datetime(2020, 3, 1)).alias('bt_jan_mar'))
# Out:
# shape: (3, 3)
# ┌────────────┬───────┬────────────┐
# │ date       ┆ index ┆ bt_jan_mar │
# │ ---        ┆ ---   ┆ ---        │
# │ date       ┆ i64   ┆ bool       │
# ╞════════════╪═══════╪════════════╡
# │ 2020-01-01 ┆ 1     ┆ false      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2020-02-03 ┆ 2     ┆ true       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2020-03-04 ┆ 3     ┆ false      │
# └────────────┴───────┴────────────┘

# %%
df_time_converted.with_columns(pl.col("date").dt.month().alias("month"))
# Out:
# shape: (3, 3)
# ┌────────────┬───────┬───────┐
# │ date       ┆ index ┆ month │
# │ ---        ┆ ---   ┆ ---   │
# │ date       ┆ i64   ┆ u32   │
# ╞════════════╪═══════╪═══════╡
# │ 2020-01-01 ┆ 1     ┆ 1     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2020-02-03 ┆ 2     ┆ 2     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2020-03-04 ┆ 3     ┆ 3     │
# └────────────┴───────┴───────┘

# %% [markdown]
# # Useful expression

# %%
df = pl.read_csv('data.csv')

# %% [markdown]
# ### Unique value in a column

# %%
df['cut'].unique().to_list()
# Out:
# ['Ideal', 'Fair', 'Very Good', 'Good', 'Premium']

# %% [markdown]
# ### Sort by column

# %%
df.sort('price', reverse=True)
# Out:
# shape: (53940, 10)
# ┌───────┬───────────┬───────┬─────────┬─────┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪═══════╪══════╪══════╪══════╡
# │ 2.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 18823 ┆ 8.5  ┆ 8.47 ┆ 5.16 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 2.0   ┆ Very Good ┆ G     ┆ SI1     ┆ ... ┆ 18818 ┆ 7.9  ┆ 7.97 ┆ 5.04 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 1.51  ┆ Ideal     ┆ G     ┆ IF      ┆ ... ┆ 18806 ┆ 7.37 ┆ 7.41 ┆ 4.56 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 2.07  ┆ Ideal     ┆ G     ┆ SI2     ┆ ... ┆ 18804 ┆ 8.2  ┆ 8.13 ┆ 5.11 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ ...   ┆ ...       ┆ ...   ┆ ...     ┆ ... ┆ ...   ┆ ...  ┆ ...  ┆ ...  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# └───────┴───────────┴───────┴─────────┴─────┴───────┴──────┴──────┴──────┘

# %% [markdown]
# ### Simple aggregation

# %%
df.select(
    [
        pl.sum("price").alias("sum"),
        pl.min("price").alias("min"),
        pl.max("price").alias("max"),
        pl.col("price").max().alias("other_max"),
        pl.std("price").alias("std dev"),
        pl.var("price").alias("variance"),
    ]
)
# Out:
# shape: (1, 6)
# ┌───────────┬─────┬───────┬───────────┬─────────────┬──────────┐
# │ sum       ┆ min ┆ max   ┆ other_max ┆ std dev     ┆ variance │
# │ ---       ┆ --- ┆ ---   ┆ ---       ┆ ---         ┆ ---      │
# │ i64       ┆ i64 ┆ i64   ┆ i64       ┆ f64         ┆ f64      │
# ╞═══════════╪═════╪═══════╪═══════════╪═════════════╪══════════╡
# │ 212135217 ┆ 326 ┆ 18823 ┆ 18823     ┆ 3989.439738 ┆ 1.5916e7 │
# └───────────┴─────┴───────┴───────────┴─────────────┴──────────┘

# %% [markdown]
# ### Binary function on a column

# %%
df.with_columns([pl.when(pl.col("price") < 1000).then('cheap').otherwise('not cheap').alias('cheap?')])
# Out:
# shape: (53940, 11)
# ┌───────┬───────────┬───────┬─────────┬─────┬──────┬──────┬──────┬───────────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ x    ┆ y    ┆ z    ┆ cheap?    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---  ┆ ---  ┆ ---  ┆ ---       │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ f64  ┆ f64  ┆ f64  ┆ str       │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪══════╪══════╪══════╪═══════════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 3.95 ┆ 3.98 ┆ 2.43 ┆ cheap     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 3.89 ┆ 3.84 ┆ 2.31 ┆ cheap     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 4.05 ┆ 4.07 ┆ 2.31 ┆ cheap     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 4.2  ┆ 4.23 ┆ 2.63 ┆ cheap     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...   ┆ ...       ┆ ...   ┆ ...     ┆ ... ┆ ...  ┆ ...  ┆ ...  ┆ ...       │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ ... ┆ 5.69 ┆ 5.75 ┆ 3.61 ┆ not cheap │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ ... ┆ 5.66 ┆ 5.68 ┆ 3.56 ┆ not cheap │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ ... ┆ 6.15 ┆ 6.12 ┆ 3.74 ┆ not cheap │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ ... ┆ 5.83 ┆ 5.87 ┆ 3.64 ┆ not cheap │
# └───────┴───────────┴───────┴─────────┴─────┴──────┴──────┴──────┴───────────┘

# %% [markdown]
# ### Window function

# %%
lazy_df = df.lazy()

# %%
lazy_df
# Out:
# <i>naive plan: (run <b>LazyFrame.describe_optimized_plan()</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DATAFRAME(in-memory): ["carat", "cut", "color", "clarity"];<p></p>	project */10 columns	|	details: None;<p></p>	selection: "None"<p></p><p></p></div>

# %%
df.with_columns([pl.col("price").sum().over("color").alias("sum[price]/color"),
                pl.col("clarity").list().over("color").alias("clarity_list/color")]).collect()
# Out:
# shape: (53940, 12)
# ┌───────┬───────────┬───────┬─────────┬─────┬──────┬──────┬──────────────────┬─────────────────────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ y    ┆ z    ┆ sum[price]/color ┆ clarity_list/color  │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---  ┆ ---  ┆ ---              ┆ ---                 │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ f64  ┆ f64  ┆ i64              ┆ list[str]           │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪══════╪══════╪══════════════════╪═════════════════════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 3.98 ┆ 2.43 ┆ 30142944         ┆ ["SI2", "SI1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "VS2"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 3.84 ┆ 2.31 ┆ 30142944         ┆ ["SI2", "SI1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "VS2"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 4.07 ┆ 2.31 ┆ 30142944         ┆ ["SI2", "SI1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "VS2"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 4.23 ┆ 2.63 ┆ 27608146         ┆ ["VS2", "VVS1", ... │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "SI1"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...   ┆ ...       ┆ ...   ┆ ...     ┆ ... ┆ ...  ┆ ...  ┆ ...              ┆ ...                 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ ... ┆ 5.75 ┆ 3.61 ┆ 21476439         ┆ ["VS2", "VS1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "SI2"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ ... ┆ 5.68 ┆ 3.56 ┆ 21476439         ┆ ["VS2", "VS1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "SI2"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ ... ┆ 6.12 ┆ 3.74 ┆ 37257301         ┆ ["SI1", "VS1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "SI2"]              │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ ... ┆ 5.87 ┆ 3.64 ┆ 21476439         ┆ ["VS2", "VS1", ...  │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆                  ┆ "SI2"]              │
# └───────┴───────────┴───────┴─────────┴─────┴──────┴──────┴──────────────────┴─────────────────────┘

# %% [markdown]
# ### Groupby

# %%
df.groupby('color').agg([pl.col('price').max().alias('max_price'), pl.col('cut').count().alias('count')])
# Out:
# shape: (7, 3)
# ┌───────┬───────────┬───────┐
# │ color ┆ max_price ┆ count │
# │ ---   ┆ ---       ┆ ---   │
# │ str   ┆ i64       ┆ u32   │
# ╞═══════╪═══════════╪═══════╡
# │ F     ┆ 18791     ┆ 9542  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ J     ┆ 18710     ┆ 2808  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ G     ┆ 18818     ┆ 11292 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ D     ┆ 18693     ┆ 6775  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ I     ┆ 18823     ┆ 5422  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ H     ┆ 18803     ┆ 8304  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ E     ┆ 18731     ┆ 9797  │
# └───────┴───────────┴───────┘

# %%
df['cut'].value_counts()
# Out:
# shape: (5, 2)
# ┌───────────┬────────┐
# │ cut       ┆ counts │
# │ ---       ┆ ---    │
# │ str       ┆ u32    │
# ╞═══════════╪════════╡
# │ Ideal     ┆ 21551  │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ Premium   ┆ 13791  │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ Very Good ┆ 12082  │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ Good      ┆ 4906   │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ Fair      ┆ 1610   │
# └───────────┴────────┘

# %% [markdown]
# ### Row wise processing

# %%
grades = pl.DataFrame(
    {
        "student": ["bas", "laura", "tim", "jenny"],
        "arithmetic": [10, 5, 6, 8],
        "biology": [4, 6, 2, 7],
        "geography": [8, 4, 9, 7],
    }
)
grades
# Out:
# shape: (4, 4)
# ┌─────────┬────────────┬─────────┬───────────┐
# │ student ┆ arithmetic ┆ biology ┆ geography │
# │ ---     ┆ ---        ┆ ---     ┆ ---       │
# │ str     ┆ i64        ┆ i64     ┆ i64       │
# ╞═════════╪════════════╪═════════╪═══════════╡
# │ bas     ┆ 10         ┆ 4       ┆ 8         │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ laura   ┆ 5          ┆ 6       ┆ 4         │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ tim     ┆ 6          ┆ 2       ┆ 9         │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ jenny   ┆ 8          ┆ 7       ┆ 7         │
# └─────────┴────────────┴─────────┴───────────┘

# %%
grades.select([pl.concat_list(pl.all().exclude("student")).alias("all_grades")])
# Out:
# shape: (4, 1)
# ┌────────────┐
# │ all_grades │
# │ ---        │
# │ list[i64]  │
# ╞════════════╡
# │ [10, 4, 8] │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [5, 6, 4]  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [6, 2, 9]  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [8, 7, 7]  │
# └────────────┘

# %%
df1 = pl.DataFrame(
    {
        "a": [1, 2, 3],
        "b": [10, 20, 30],
    }
)

out = df1.select(
    pl.fold(acc=pl.lit(2), f=lambda acc, x: acc + x, exprs=pl.col("*")).alias("sum"),
)

out
# Out:
# shape: (3, 1)
# ┌─────┐
# │ sum │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 13  │
# ├╌╌╌╌╌┤
# │ 24  │
# ├╌╌╌╌╌┤
# │ 35  │
# └─────┘

# %% [markdown]
# ### Apply custom function

# %%
import collections

def add_prefix(string):
    return 'very ' + string

df.with_columns(pl.col('cut').apply(add_prefix).alias('cut_with_pre'))
# Out:
# shape: (53940, 11)
# ┌───────┬───────────┬───────┬─────────┬─────┬──────┬──────┬──────┬────────────────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ x    ┆ y    ┆ z    ┆ cut_with_pre   │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---  ┆ ---  ┆ ---  ┆ ---            │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ f64  ┆ f64  ┆ f64  ┆ str            │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪══════╪══════╪══════╪════════════════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 3.95 ┆ 3.98 ┆ 2.43 ┆ very Ideal     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 3.89 ┆ 3.84 ┆ 2.31 ┆ very Premium   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 4.05 ┆ 4.07 ┆ 2.31 ┆ very Good      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 4.2  ┆ 4.23 ┆ 2.63 ┆ very Premium   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...   ┆ ...       ┆ ...   ┆ ...     ┆ ... ┆ ...  ┆ ...  ┆ ...  ┆ ...            │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ ... ┆ 5.69 ┆ 5.75 ┆ 3.61 ┆ very Good      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ ... ┆ 5.66 ┆ 5.68 ┆ 3.56 ┆ very Very Good │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ ... ┆ 6.15 ┆ 6.12 ┆ 3.74 ┆ very Premium   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ ... ┆ 5.83 ┆ 5.87 ┆ 3.64 ┆ very Ideal     │
# └───────┴───────────┴───────┴─────────┴─────┴──────┴──────┴──────┴────────────────┘

# %% [markdown]
# ## Lazy related

# %%
lazy_select_df = pl.scan_csv("data.csv").select(['carat', 'cut', 'color'])

# %%
lazy_select_df
# Out:
# <i>naive plan: (run <b>LazyFrame.describe_optimized_plan()</b> to see the optimized plan)</i>
#     <p></p>
#     <div>SELECT 3 COLUMNS: [col("carat"), col("cut"), col("color")]<p></p>FROM<p></p>CSV SCAN data.csv; PROJECT */10 COLUMNS; SELECTION: None</div>

# %% [markdown]
# ## polars expression (parallel process for each column)

# %% [markdown]
# each item in the list represent one process

# %% [markdown]
# alias create a column with the desire column name

# %%
df.select([
    pl.col('cut').n_unique().alias('numbers of unique in cut'),
    pl.col('clarity').n_unique().alias('numbers of unique in clarity')
])
# Out:
# shape: (1, 2)
# ┌──────────────────────────┬──────────────────────────────┐
# │ numbers of unique in cut ┆ numbers of unique in clarity │
# │ ---                      ┆ ---                          │
# │ u32                      ┆ u32                          │
# ╞══════════════════════════╪══════════════════════════════╡
# │ 5                        ┆ 8                            │
# └──────────────────────────┴──────────────────────────────┘

# %% [markdown]
# aggregation:

# %% [markdown]
# if statement

# %%
df.select([
    pl.col('price'),
    pl.when(pl.col('price') > 1000).then(True).otherwise(False).alias('test')
])
# Out:
# shape: (53940, 2)
# ┌───────┬───────┐
# │ price ┆ test  │
# │ ---   ┆ ---   │
# │ i64   ┆ bool  │
# ╞═══════╪═══════╡
# │ 326   ┆ false │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 326   ┆ false │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 327   ┆ false │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 334   ┆ false │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ ...   ┆ ...   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2757  ┆ true  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2757  ┆ true  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2757  ┆ true  │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2757  ┆ true  │
# └───────┴───────┘

# %% [markdown]
# window function

# %%
df[
    [
        pl.col('*'), # select all
        pl.col('price').sum().over('cut').alias('sum of the correspond group'),
        pl.col('clarity').list().over('cut').alias('full list of the correspond group')
    ]
]
# Out:
# shape: (53940, 12)
# ┌───────┬───────────┬───────┬─────────┬─────┬──────┬──────┬──────────┬─────────────────────────────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ y    ┆ z    ┆ sum of   ┆ full list of the correspond │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---  ┆ ---  ┆ the corr ┆ grou...                     │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ f64  ┆ f64  ┆ espond   ┆ ---                         │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆ group    ┆ list[str]                   │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆ ---      ┆                             │
# │       ┆           ┆       ┆         ┆     ┆      ┆      ┆ i64      ┆                             │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪══════╪══════╪══════════╪═════════════════════════════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 3.98 ┆ 2.43 ┆ 74513487 ┆ ["SI2", "VS1", ... "SI2"]   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 3.84 ┆ 2.31 ┆ 63221498 ┆ ["SI1", "VS2", ... "SI2"]   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 4.07 ┆ 2.31 ┆ 19275009 ┆ ["VS1", "SI2", ... "SI1"]   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 4.23 ┆ 2.63 ┆ 63221498 ┆ ["SI1", "VS2", ... "SI2"]   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...   ┆ ...       ┆ ...   ┆ ...     ┆ ... ┆ ...  ┆ ...  ┆ ...      ┆ ...                         │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.72  ┆ Good      ┆ D     ┆ SI1     ┆ ... ┆ 5.75 ┆ 3.61 ┆ 19275009 ┆ ["VS1", "SI2", ... "SI1"]   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.7   ┆ Very Good ┆ D     ┆ SI1     ┆ ... ┆ 5.68 ┆ 3.56 ┆ 48107623 ┆ ["VVS2", "VVS1", ... "SI1"] │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.86  ┆ Premium   ┆ H     ┆ SI2     ┆ ... ┆ 6.12 ┆ 3.74 ┆ 63221498 ┆ ["SI1", "VS2", ... "SI2"]   │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.75  ┆ Ideal     ┆ D     ┆ SI2     ┆ ... ┆ 5.87 ┆ 3.64 ┆ 74513487 ┆ ["SI2", "VS1", ... "SI2"]   │
# └───────┴───────────┴───────┴─────────┴─────┴──────┴──────┴──────────┴─────────────────────────────┘

# %%
df.head(6)
# Out:
# shape: (6, 10)
# ┌───────┬───────────┬───────┬─────────┬─────┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ ... ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.24  ┆ Very Good ┆ J     ┆ VVS2    ┆ ... ┆ 336   ┆ 3.94 ┆ 3.96 ┆ 2.48 │
# └───────┴───────────┴───────┴─────────┴─────┴───────┴──────┴──────┴──────┘

# %% [markdown]
# groupby

# %%
df.groupby('cut').agg([
    pl.col('price').sum().suffix('_sum'),
    pl.col('price').count().alias('count of memeber'),
    pl.col('depth').min().suffix('_min')
])
# Out:
# shape: (5, 4)
# ┌───────────┬───────────┬──────────────────┬───────────┐
# │ cut       ┆ price_sum ┆ count of memeber ┆ depth_min │
# │ ---       ┆ ---       ┆ ---              ┆ ---       │
# │ str       ┆ i64       ┆ u32              ┆ f64       │
# ╞═══════════╪═══════════╪══════════════════╪═══════════╡
# │ Premium   ┆ 63221498  ┆ 13791            ┆ 58.0      │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ Fair      ┆ 7017600   ┆ 1610             ┆ 43.0      │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ Ideal     ┆ 74513487  ┆ 21551            ┆ 43.0      │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ Good      ┆ 19275009  ┆ 4906             ┆ 54.3      │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ Very Good ┆ 48107623  ┆ 12082            ┆ 56.8      │
# └───────────┴───────────┴──────────────────┴───────────┘

# %%
process = (df.lazy().groupby('cut').agg([
    pl.count(),
    pl.col('price').sum(),
    pl.col('depth').min()
]).sort('count', reverse=True).limit(3))

# %%
process.collect()
# Out:
# shape: (3, 4)
# ┌───────────┬───────┬──────────┬───────┐
# │ cut       ┆ count ┆ price    ┆ depth │
# │ ---       ┆ ---   ┆ ---      ┆ ---   │
# │ str       ┆ u32   ┆ i64      ┆ f64   │
# ╞═══════════╪═══════╪══════════╪═══════╡
# │ Ideal     ┆ 21551 ┆ 74513487 ┆ 43.0  │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ Premium   ┆ 13791 ┆ 63221498 ┆ 58.0  │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ Very Good ┆ 12082 ┆ 48107623 ┆ 56.8  │
# └───────────┴───────┴──────────┴───────┘

# %% [markdown]
# horizontal accumulation

# %%
df.select([(pl.col('price') + pl.col('depth')).alias('p+d2')])
# Out:
# shape: (53940, 1)
# ┌────────┐
# │ p+d2   │
# │ ---    │
# │ f64    │
# ╞════════╡
# │ 387.5  │
# ├╌╌╌╌╌╌╌╌┤
# │ 385.8  │
# ├╌╌╌╌╌╌╌╌┤
# │ 383.9  │
# ├╌╌╌╌╌╌╌╌┤
# │ 396.4  │
# ├╌╌╌╌╌╌╌╌┤
# │ ...    │
# ├╌╌╌╌╌╌╌╌┤
# │ 2820.1 │
# ├╌╌╌╌╌╌╌╌┤
# │ 2819.8 │
# ├╌╌╌╌╌╌╌╌┤
# │ 2818.0 │
# ├╌╌╌╌╌╌╌╌┤
# │ 2819.2 │
# └────────┘

# %%
df.head(6)
# Out:
# shape: (6, 10)
# ┌───────┬───────────┬───────┬─────────┬─────┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut       ┆ color ┆ clarity ┆ ... ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---       ┆ ---   ┆ ---     ┆     ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str       ┆ str   ┆ str     ┆     ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═══════════╪═══════╪═════════╪═════╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal     ┆ E     ┆ SI2     ┆ ... ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium   ┆ E     ┆ SI1     ┆ ... ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.23  ┆ Good      ┆ E     ┆ VS1     ┆ ... ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.29  ┆ Premium   ┆ I     ┆ VS2     ┆ ... ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.31  ┆ Good      ┆ J     ┆ SI2     ┆ ... ┆ 335   ┆ 4.34 ┆ 4.35 ┆ 2.75 │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 0.24  ┆ Very Good ┆ J     ┆ VVS2    ┆ ... ┆ 336   ┆ 3.94 ┆ 3.96 ┆ 2.48 │
# └───────┴───────────┴───────┴─────────┴─────┴───────┴──────┴──────┴──────┘

# %%
df.filter(pl.col('color')=="E").select(['carat', 'cut', 'color']).head(5)
# Out:
# shape: (5, 3)
# ┌───────┬─────────┬───────┐
# │ carat ┆ cut     ┆ color │
# │ ---   ┆ ---     ┆ ---   │
# │ f64   ┆ str     ┆ str   │
# ╞═══════╪═════════╪═══════╡
# │ 0.23  ┆ Ideal   ┆ E     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0.21  ┆ Premium ┆ E     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0.23  ┆ Good    ┆ E     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0.22  ┆ Fair    ┆ E     │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0.2   ┆ Premium ┆ E     │
# └───────┴─────────┴───────┘

# %% [markdown]
# # Pokemon dataset

# %%
df = pl.read_csv(
    "https://gist.githubusercontent.com/ritchie46/cac6b337ea52281aa23c049250a4ff03/raw/89a957ff3919d90e6ef2d34235e6bf22304f3366/pokemon.csv"
)

# %%
df.head(10)
# Out:
# shape: (10, 13)
# ┌─────┬─────────────────────────┬────────┬────────┬─────┬─────────┬───────┬────────────┬───────────┐
# │ #   ┆ Name                    ┆ Type 1 ┆ Type 2 ┆ ... ┆ Sp. Def ┆ Speed ┆ Generation ┆ Legendary │
# │ --- ┆ ---                     ┆ ---    ┆ ---    ┆     ┆ ---     ┆ ---   ┆ ---        ┆ ---       │
# │ i64 ┆ str                     ┆ str    ┆ str    ┆     ┆ i64     ┆ i64   ┆ i64        ┆ bool      │
# ╞═════╪═════════════════════════╪════════╪════════╪═════╪═════════╪═══════╪════════════╪═══════════╡
# │ 1   ┆ Bulbasaur               ┆ Grass  ┆ Poison ┆ ... ┆ 65      ┆ 45    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2   ┆ Ivysaur                 ┆ Grass  ┆ Poison ┆ ... ┆ 80      ┆ 60    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3   ┆ Venusaur                ┆ Grass  ┆ Poison ┆ ... ┆ 100     ┆ 80    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3   ┆ VenusaurMega Venusaur   ┆ Grass  ┆ Poison ┆ ... ┆ 120     ┆ 80    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ... ┆ ...                     ┆ ...    ┆ ...    ┆ ... ┆ ...     ┆ ...   ┆ ...        ┆ ...       │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 6   ┆ Charizard               ┆ Fire   ┆ Flying ┆ ... ┆ 85      ┆ 100   ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 6   ┆ CharizardMega Charizard ┆ Fire   ┆ Dragon ┆ ... ┆ 85      ┆ 100   ┆ 1          ┆ false     │
# │     ┆ X                       ┆        ┆        ┆     ┆         ┆       ┆            ┆           │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 6   ┆ CharizardMega Charizard ┆ Fire   ┆ Flying ┆ ... ┆ 115     ┆ 100   ┆ 1          ┆ false     │
# │     ┆ Y                       ┆        ┆        ┆     ┆         ┆       ┆            ┆           │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7   ┆ Squirtle                ┆ Water  ┆ null   ┆ ... ┆ 64      ┆ 43    ┆ 1          ┆ false     │
# └─────┴─────────────────────────┴────────┴────────┴─────┴─────────┴───────┴────────────┴───────────┘

# %%
df.sort('Type 1')
# Out:
# shape: (163, 13)
# ┌─────┬───────────────────────┬────────┬────────┬─────┬─────────┬───────┬────────────┬───────────┐
# │ #   ┆ Name                  ┆ Type 1 ┆ Type 2 ┆ ... ┆ Sp. Def ┆ Speed ┆ Generation ┆ Legendary │
# │ --- ┆ ---                   ┆ ---    ┆ ---    ┆     ┆ ---     ┆ ---   ┆ ---        ┆ ---       │
# │ i64 ┆ str                   ┆ str    ┆ str    ┆     ┆ i64     ┆ i64   ┆ i64        ┆ bool      │
# ╞═════╪═══════════════════════╪════════╪════════╪═════╪═════════╪═══════╪════════════╪═══════════╡
# │ 10  ┆ Caterpie              ┆ Bug    ┆ null   ┆ ... ┆ 20      ┆ 45    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 11  ┆ Metapod               ┆ Bug    ┆ null   ┆ ... ┆ 25      ┆ 30    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 12  ┆ Butterfree            ┆ Bug    ┆ Flying ┆ ... ┆ 80      ┆ 70    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 13  ┆ Weedle                ┆ Bug    ┆ Poison ┆ ... ┆ 20      ┆ 50    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ... ┆ ...                   ┆ ...    ┆ ...    ┆ ... ┆ ...     ┆ ...   ┆ ...        ┆ ...       │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 130 ┆ Gyarados              ┆ Water  ┆ Flying ┆ ... ┆ 100     ┆ 81    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 130 ┆ GyaradosMega Gyarados ┆ Water  ┆ Dark   ┆ ... ┆ 130     ┆ 81    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 131 ┆ Lapras                ┆ Water  ┆ Ice    ┆ ... ┆ 95      ┆ 60    ┆ 1          ┆ false     │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 134 ┆ Vaporeon              ┆ Water  ┆ null   ┆ ... ┆ 95      ┆ 65    ┆ 1          ┆ false     │
# └─────┴───────────────────────┴────────┴────────┴─────┴─────────┴───────┴────────────┴───────────┘

# %%
df.sort("Type 1").select(
    [pl.col("Type 1").head(3).list().over("Type 1").flatten(), ])
# Out:
# shape: (43, 1)
# ┌────────┐
# │ Type 1 │
# │ ---    │
# │ str    │
# ╞════════╡
# │ Bug    │
# ├╌╌╌╌╌╌╌╌┤
# │ Bug    │
# ├╌╌╌╌╌╌╌╌┤
# │ Bug    │
# ├╌╌╌╌╌╌╌╌┤
# │ Dragon │
# ├╌╌╌╌╌╌╌╌┤
# │ ...    │
# ├╌╌╌╌╌╌╌╌┤
# │ Rock   │
# ├╌╌╌╌╌╌╌╌┤
# │ Water  │
# ├╌╌╌╌╌╌╌╌┤
# │ Water  │
# ├╌╌╌╌╌╌╌╌┤
# │ Water  │
# └────────┘

# %%
grades = pl.DataFrame(
    {
        "student": ["bas", "laura", "tim", "jenny"],
        "arithmetic": [10, 5, 6, 8],
        "biology": [4, 6, 2, 7],
        "geography": [8, 4, 9, 7],
    }
)

# %%
grades.with_column(
    # create the list of homogeneous data
    pl.concat_list(pl.all().exclude("student")).alias("all_grades")
)
# Out:
# shape: (4, 5)
# ┌─────────┬────────────┬─────────┬───────────┬────────────┐
# │ student ┆ arithmetic ┆ biology ┆ geography ┆ all_grades │
# │ ---     ┆ ---        ┆ ---     ┆ ---       ┆ ---        │
# │ str     ┆ i64        ┆ i64     ┆ i64       ┆ list[i64]  │
# ╞═════════╪════════════╪═════════╪═══════════╪════════════╡
# │ bas     ┆ 10         ┆ 4       ┆ 8         ┆ [10, 4, 8] │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ laura   ┆ 5          ┆ 6       ┆ 4         ┆ [5, 6, 4]  │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ tim     ┆ 6          ┆ 2       ┆ 9         ┆ [6, 2, 9]  │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ jenny   ┆ 8          ┆ 7       ┆ 7         ┆ [8, 7, 7]  │
# └─────────┴────────────┴─────────┴───────────┴────────────┘

# %% [markdown]
# ## undefine

# %%
df['x'].apply(round)
# Out:
# shape: (53940,)
# Series: 'x' [i64]
# [
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	...
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# ]

# %%
df['x'].apply(lambda x: round(x))
# Out:
# shape: (53940,)
# Series: 'x' [i64]
# [
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	4
# 	...
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# 	6
# ]

# %%
mydict = {v:k for k,v in enumerate(df['cut'].unique())}

# %%
mydict
# Out:
# {'Ideal': 0, 'Premium': 1, 'Good': 2, 'Very Good': 3, 'Fair': 4}

# %%
import polars.lazy as plz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 import polars.lazy as plz
#
# ModuleNotFoundError: No module named 'polars.lazy'

# %%
l_df = df.lazy()

# %%
type(l_df)
# Out:
# polars.internals.lazy_frame.LazyFrame

# %%
l_df
# Out:
# <i>naive plan: (run <b>LazyFrame.describe_optimized_plan()</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DATAFRAME(in-memory): ["carat", "cut", "color", "clarity"];<p></p>	project */10 columns	|	details: None;<p></p>	selection: "None"<p></p><p></p></div>

# %%
df.groupby('cut').
# Out:
# shape: (5,)
# Series: 'price' [i64]
# [
# 	63221498
# 	48107623
# 	74513487
# 	7017600
# 	19275009
# ]
